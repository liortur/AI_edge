# %%
import pandas as pd
import numpy as np
from sklearn import cross_validation
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import pickle
import time
import sys 
# import data set (change library)
train = pd.read_csv("*/MNIST_data.csv")
features = train.columns[1:]
X = train[features]
y = train['label']
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X/255.,y,test_size=0.1,random_state=0)

#train NN model
clf_nn = MLPClassifier(hidden_layer_sizes=(200, 20), activation = 'logistic', max_iter=150, alpha=1e-4,
                    solver='sgd', verbose=10, tol=1e-4, random_state=1,
                    learning_rate_init=.1)

clf_nn.fit(X_train, y_train)
acc_nn = clf_nn.score(X_test,y_test)
print ("neural network accuracy: ",acc_nn)

# save the classifier
with open('*/MNIST_NN_big.pkl', 'wb') as fid:
    pickle.dump(clf_nn, fid)
# Out:
# Iteration 1, loss = 1.52671235
# Iteration 2, loss = 0.47858519
# Iteration 3, loss = 0.33370660
# Iteration 4, loss = 0.28239305
# Iteration 5, loss = 0.24627468
# Iteration 6, loss = 0.21633271
# Iteration 7, loss = 0.19033763
# Iteration 8, loss = 0.16868185
# Iteration 9, loss = 0.14949100
# Iteration 10, loss = 0.13475299
# Iteration 11, loss = 0.12163273
# Iteration 12, loss = 0.11078675
# Iteration 13, loss = 0.10122043
# Iteration 14, loss = 0.09234357
# Iteration 15, loss = 0.08547685
# Iteration 16, loss = 0.07890998
# Iteration 17, loss = 0.07227747
# Iteration 18, loss = 0.06708541
# Iteration 19, loss = 0.06128277
# Iteration 20, loss = 0.05683805
# Iteration 21, loss = 0.05288207
# Iteration 22, loss = 0.04870638
# Iteration 23, loss = 0.04523540
# Iteration 24, loss = 0.04179553
# Iteration 25, loss = 0.03892884
# Iteration 26, loss = 0.03604262
# Iteration 27, loss = 0.03353198
# Iteration 28, loss = 0.03077930
# Iteration 29, loss = 0.02853615
# Iteration 30, loss = 0.02672047
# Iteration 31, loss = 0.02432583
# Iteration 32, loss = 0.02278874
# Iteration 33, loss = 0.02092036
# Iteration 34, loss = 0.01949898
# Iteration 35, loss = 0.01821608
# Iteration 36, loss = 0.01679859
# Iteration 37, loss = 0.01567832
# Iteration 38, loss = 0.01477610
# Iteration 39, loss = 0.01394471
# Iteration 40, loss = 0.01304073
# Iteration 41, loss = 0.01210190
# Iteration 42, loss = 0.01139471
# Iteration 43, loss = 0.01091370
# Iteration 44, loss = 0.01027423
# Iteration 45, loss = 0.00956796
# Iteration 46, loss = 0.00909393
# Iteration 47, loss = 0.00872371
# Iteration 48, loss = 0.00811860
# Iteration 49, loss = 0.00781883
# Iteration 50, loss = 0.00743521
# Iteration 51, loss = 0.00712303
# Iteration 52, loss = 0.00673799
# Iteration 53, loss = 0.00653271
# Iteration 54, loss = 0.00624737
# Iteration 55, loss = 0.00588232
# Iteration 56, loss = 0.00567373
# Iteration 57, loss = 0.00549404
# Iteration 58, loss = 0.00527142
# Iteration 59, loss = 0.00510537
# Iteration 60, loss = 0.00491211
# Iteration 61, loss = 0.00473702
# Iteration 62, loss = 0.00460923
# Iteration 63, loss = 0.00439124
# Iteration 64, loss = 0.00436052
# Iteration 65, loss = 0.00418054
# Iteration 66, loss = 0.00405012
# Iteration 67, loss = 0.00392681
# Iteration 68, loss = 0.00383419
# Iteration 69, loss = 0.00374716
# Iteration 70, loss = 0.00365296
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# neural network accuracy:  0.9719047619047619

# %%
# load saved model
with open('*/MNIST_NN_big.pkl', 'rb') as fid:
    nn_loaded = pickle.load(fid)

# model size
print ('model size=',sys.getsizeof(pickle.dumps(nn_loaded)))    

# run model for test set
test = pd.read_csv("*/test.csv")

# prediction time
start_time = time.time()
predict = nn_loaded.predict(test)
end_time = time.time()

print('Test predictions:', predict)
print ("Overall prediction time:", end_time - start_time)
# Out:
# model size= 2586457
# Test predictions: [2 0 9 ... 3 9 2]
# Overall prediction time: 0.32114410400390625
